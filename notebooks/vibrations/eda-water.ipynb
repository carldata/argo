# %% [markdown]
# # EDA Water Flow
#
# The following datasets are sampled with the frequency 500Hz

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 4

# %% [markdown]
# # Load data

# %%
data_frame = pd.read_csv('../../datasets/vibrations/argo-data_water-only.csv')
data_frame.head()
# Out:
#        x      y      z  flow   temp
# 0  63757  65509  12977     0  65024
# 1  63733  65511  13004     0  65024
# 2  63727  65495  12995     0  65024
# 3  63734  65508  12993     0  65024
# 4  63748  65477  12982     0  65024

# %% [markdown]
# # Plot columns

# %% [markdown]
# ## Flow

# %%
data_frame.flow.plot()
plt.show()

# %% [markdown]
# ## Temperature

# %%
data_frame.temp.plot()
plt.show()

# %% [markdown]
# ## Vibration sensor

# %%
NFFT = 128
noverlap = NFFT / 4

print('x')
plt.specgram(data_frame.x, Fs=500, NFFT=NFFT, noverlap=noverlap)
plt.show()

print('y')
plt.specgram(data_frame.y, Fs=500, NFFT=NFFT, noverlap=noverlap)
plt.show()

print('z')
plt.specgram(data_frame.z, Fs=500, NFFT=NFFT, noverlap=noverlap)
plt.show()
# Out:
# x
# y
# z
