# %% [markdown]
# # Exploratory plots

# %%
import datetime
import calendar
import pprint
import json
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 4

# %% [markdown]
# # Load project

# %%
project_folder = '../../datasets/radon-small/'
df = pd.read_csv(project_folder + 'flow1.csv', parse_dates=['time'])
flow = df.set_index('time')['flow'].fillna(0)
flow.head()
# Out:
# time
# 2013-09-09 10:50:00     2.805
# 2013-09-09 10:55:00     2.796
# 2013-09-09 11:00:00     2.791
# 2013-09-09 11:05:00    46.680
# 2013-09-09 11:10:00    48.030
# Name: flow, dtype: float64

# %% [markdown]
# ## Helper functions

# %%
def plot_days(start_day, end_day):
    """Plot series for specific data range"""
    df = flow[pd.Timestamp(start_day): pd.Timestamp(end_day)]
    df.plot()
    plt.show()

# %% [markdown]
# # Plot the whole series

# %%
flow.plot()
plt.show()

# %% [markdown]
# From the plot it looks that we might have some outliers here.
#
# But it is also possible that the bigger values are correct responses to the rain we need to look closer to this data.

# %% [markdown]
# # Explore november 2013

# %%
plot_days('2013-11-01', '2013-12-01')

# %% [markdown]
# Lets looks closer to the "standard" day and the day with outlier

# %% [markdown]
# And now some days with anomalies

# %%
plot_days('2013-11-01', '2013-11-03')

# %%
plot_days('2013-11-02T18:00', '2013-11-02T20:00')

# %% [markdown]
# It looks that probably here we have some reading problem which results in outlier

# %% [markdown]
# ## Lets check some flow in Spring

# %%
plot_days('2014-06-01', '2014-07-01')

# %%
plot_days('2014-06-11', '2014-06-13')

# %%
plot_days('2014-06-17', '2014-06-18')

# %% [markdown]
# Here are 2 high values which can be results of rainfall or maybe some errors in reading
