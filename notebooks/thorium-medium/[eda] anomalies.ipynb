# %% [markdown]
# # Anomaly detection on Toronto data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 4

# %% [markdown]
# ## Load data

# %%
project_folder = '../../datasets/thorium-medium/'
df_rain = pd.read_csv(project_folder + 'rainfall1.csv', parse_dates=['time'])
rain = df_rain.set_index('time')['rainfall'].fillna(0)
df_flow = pd.read_csv(project_folder + 'flow1.csv', parse_dates=['time'])
flow = df_flow.set_index('time')['flow'].fillna(0)
df = pd.concat([flow, rain], axis=1)
df
# Out:
#                            flow  rainfall
# time
# 2015-04-29 08:50:00         NaN       0.0
# 2015-04-29 08:55:00         NaN       0.0
# 2015-04-29 09:00:00         NaN       0.0
# 2015-04-29 09:05:00         NaN       0.0
# 2015-04-29 09:10:00         NaN       0.0
# 2015-04-29 09:15:00         NaN       0.0
# 2015-04-29 09:20:00         NaN       0.0
# 2015-04-29 09:25:00         NaN       0.0
# 2015-04-29 09:30:00         NaN       0.0
# 2015-04-29 09:35:00         NaN       0.0
# 2015-04-29 09:40:00         NaN       0.0
# 2015-04-29 09:45:00         NaN       0.0
# 2015-04-29 09:50:00         NaN       0.0
# 2015-04-29 09:55:00         NaN       0.0
# 2015-04-29 10:00:00         NaN       0.0
# 2015-04-29 10:05:00         NaN       0.0
# 2015-04-29 10:10:00         NaN       0.0
# 2015-04-29 10:15:00         NaN       0.0
# 2015-04-29 10:20:00         NaN       0.0
# 2015-04-29 10:25:00         NaN       0.0
# 2015-04-29 10:30:00         NaN       0.0
# ...
